# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset=pd.read_csv("C:\\Users\\hp\\Desktop\\DL PR\\Boston.csv")
dataset
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
dataset.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat       Price
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
dataset.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  Price
# 501  391.99   9.67   22.4
# 502  396.90   9.08   20.6
# 503  396.90   5.64   23.9
# 504  393.45   6.48   22.0
# 505  396.90   7.88   11.9

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
dataset.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# Price      0
# dtype: int64

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.DataFrame()

# %%
import seaborn as sns
sns.distplot(dataset.Price)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(dataset.Price)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
correlation = dataset.corr()
correlation.loc['Price']
# Out:
# crim      -0.388305
# zn         0.360445
# indus     -0.483725
# chas       0.175260
# nox       -0.427321
# rm         0.695360
# age       -0.376955
# dis        0.249929
# rad       -0.381626
# tax       -0.468536
# ptratio   -0.507787
# black      0.333461
# lstat     -0.737663
# Price      1.000000
# Name: Price, dtype: float64

# %%
fig,axes = plt.subplots(figsize=(15,12))
sns.heatmap(correlation,square = True,annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (20,5))
features = ['lstat','rm','ptratio']
for i, col in enumerate(features):
 plt.subplot(1, len(features) , i+1)
 x = dataset[col]
 y = dataset.Price
 plt.scatter(x, y, marker='o')
 plt.title("Variation in House prices")
 plt.xlabel(col)
 plt.ylabel('"House prices in $1000"')

# %%
X = dataset.iloc[:,:-1]
y= dataset.Price

# %%
dataset.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'Price'],
#       dtype='object')

# %%
dataset.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'Price'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# Price      float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404,)
# (102,)
# (404,)
# (102,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
x = dataset.iloc[:,:-1]
y = dataset.Price

# %%
mean = x_train.mean(axis=0)
std = x_train.std(axis=0)
x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(dataset['Price'], bins=30)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x=pd.DataFrame(np.c_[dataset['lstat'], dataset['rm']],columns=['lstat','rm'])
y=dataset['Price']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %%
plt.figure(figsize=(20,5))
features=['lstat','rm']
target=dataset['Price']
for i,col in enumerate(features):
    plt.subplot(1,len(features),i+1)
x=dataset[col]
y=target
plt.scatter(x,y,marker='o')
plt.title(col)
plt.xlabel(col)
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
lin_model = LinearRegression()
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predict=lin_model.predict(x_train)
rmse=(np.sqrt(mean_squared_error(y_train,y_train_predict)))
r2=r2_score(y_train,y_train_predict)
print("The model performace for Training")
print(" ")
print('RMSE is{}',format(rmse))
print('R2 score is{}',format(r2))
print("\n")
# Out:
# The model performace for Training
#
# RMSE is{} 5.3656571342244215
# R2 score is{} 0.6618625964841895

# %%
y_test_predict=lin_model.predict(x_test)
rmse=(np.sqrt(mean_squared_error(y_test,y_test_predict)))
r2=r2_score(y_test,y_test_predict)
print("The model performace for Training")
print(" ")
print('RMSE is{}',format(rmse))
print('R2 score is{}',format(r2))
print("\n")
# Out:
# The model performace for Training
#
# RMSE is{} 6.114172522817782
# R2 score is{} 0.5409084827186417

# %%
plt.scatter(y_test,y_test_predict)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
import keras
from keras.layers import Dense, Activation,Dropout 
from keras.models import Sequential
model = Sequential()
model.add(Dense(128,activation = 'relu',input_dim =13)) 
model.add(Dense(64,activation = 'relu' ))
model.add(Dense(32,activation = 'relu')) 
model.add(Dense(16,activation = 'relu')) 
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mae']) 
model.compile(optimizer = 'adam',loss ='mean_squared_error',metrics=['mae'])

# %%
# !pip install ann_visualizer
# Out:
# Requirement already satisfied: ann_visualizer in c:\users\hp\anaconda3\lib\site-packages (2.5)

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#      -------------------------------------- 47.1/47.1 kB 181.7 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
from ann_visualizer.visualize import ann_viz;

# %%
import keras

from keras.layers import Dense, Activation,Dropout
from keras.models import Sequential

model = Sequential()
model.add(Dense(128,activation= 'relu',input_shape=(x_train[0].shape)))
model.add(Dense(64,activation = 'relu'))

model.add(Dense(32,activation = 'relu'))
model.add(Dense(16,activation = 'relu'))
model.add(Dense(1))

# %%
x_train[0]

# %%
k=4
num_epochs=100
num_samples=len(x_train)
all_scores=[]
model.compile(optimizer='adam', loss='mse', metrics=['mae']) 
history = model.fit(x_train, y_train,epochs=num_epochs,verbose=1,batch_size=1,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 404/404 [==============================] - 7s 6ms/step - loss: 15.9983 - mae: 2.8345 - val_loss: 29.0445 - val_mae: 3.0641
# Epoch 2/100
# 404/404 [==============================] - 2s 5ms/step - loss: 16.2475 - mae: 2.8606 - val_loss: 29.9588 - val_mae: 3.1351
# Epoch 3/100
# 404/404 [==============================] - 2s 5ms/step - loss: 15.8942 - mae: 2.8093 - val_loss: 29.9309 - val_mae: 3.1432
# Epoch 4/100
# 404/404 [==============================] - 2s 5ms/step - loss: 15.4711 - mae: 2.7731 - val_loss: 34.3276 - val_mae: 3.4623
# Epoch 5/100
# 404/404 [==============================] - 2s 5ms/step - loss: 15.0172 - mae: 2.7607 - val_loss: 29.7881 - val_mae: 3.1514
# Epoch 6/100
# 404/404 [==============================] - 2s 6ms/step - loss: 15.5531 - mae: 2.8130 - val_loss: 28.6579 - val_mae: 3.1780
# Epoch 7/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.8625 - mae: 2.7596 - val_loss: 30.2424 - val_mae: 3.1742
# Epoch 8/100
# 404/404 [==============================] - 4s 9ms/step - loss: 15.3499 - mae: 2.8178 - val_loss: 29.5164 - val_mae: 3.1073
# Epoch 9/100
# 404/404 [==============================] - 4s 9ms/step - loss: 15.3300 - mae: 2.7136 - val_loss: 34.6393 - val_mae: 3.5219
# Epoch 10/100
# 404/404 [==============================] - 4s 9ms/step - loss: 16.9321 - mae: 2.8613 - val_loss: 28.7489 - val_mae: 3.0980
# Epoch 11/100
# 404/404 [==============================] - 3s 8ms/step - loss: 14.9159 - mae: 2.7756 - val_loss: 29.7068 - val_mae: 3.1383
# Epoch 12/100
# 404/404 [==============================] - 3s 9ms/step - loss: 15.0170 - mae: 2.7375 - val_loss: 28.1819 - val_mae: 3.2364
# Epoch 13/100
# 404/404 [==============================] - 4s 9ms/step - loss: 14.9901 - mae: 2.7408 - val_loss: 30.0070 - val_mae: 3.6412
# Epoch 14/100
# 404/404 [==============================] - 4s 9ms/step - loss: 15.1809 - mae: 2.7596 - val_loss: 29.4407 - val_mae: 3.2776
# Epoch 15/100
# 404/404 [==============================] - 4s 9ms/step - loss: 14.8235 - mae: 2.7637 - val_loss: 31.8190 - val_mae: 3.7206
# Epoch 16/100
# 404/404 [==============================] - 4s 9ms/step - loss: 15.1973 - mae: 2.7467 - val_loss: 30.4453 - val_mae: 3.3637
# Epoch 17/100
# 404/404 [==============================] - 3s 9ms/step - loss: 16.2430 - mae: 2.8052 - val_loss: 28.3490 - val_mae: 3.0797
# Epoch 18/100
# 404/404 [==============================] - 4s 9ms/step - loss: 15.3777 - mae: 2.7950 - val_loss: 28.5607 - val_mae: 3.1101
# Epoch 19/100
# 404/404 [==============================] - 3s 9ms/step - loss: 14.8738 - mae: 2.7193 - val_loss: 31.3609 - val_mae: 3.2569
# Epoch 20/100
# 404/404 [==============================] - 4s 9ms/step - loss: 15
100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.7891 - mae: 2.6889 - val_loss: 30.5132 - val_mae: 3.6842
# Epoch 70/100
# 404/404 [==============================] - 2s 5ms/step - loss: 15.1506 - mae: 2.7911 - val_loss: 33.7909 - val_mae: 3.4376
# Epoch 71/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.4010 - mae: 2.7349 - val_loss: 28.6333 - val_mae: 3.1776
# Epoch 72/100
# 404/404 [==============================] - 3s 6ms/step - loss: 14.3706 - mae: 2.6999 - val_loss: 30.0557 - val_mae: 3.1690
# Epoch 73/100
# 404/404 [==============================] - 2s 6ms/step - loss: 15.0134 - mae: 2.6868 - val_loss: 34.7433 - val_mae: 4.2841
# Epoch 74/100
# 404/404 [==============================] - 3s 6ms/step - loss: 14.8837 - mae: 2.7240 - val_loss: 28.3057 - val_mae: 3.1798
# Epoch 75/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.8878 - mae: 2.7668 - val_loss: 28.9842 - val_mae: 3.0368
# Epoch 76/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.9323 - mae: 2.7097 - val_loss: 30.3268 - val_mae: 3.2002
# Epoch 77/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.8063 - mae: 2.7207 - val_loss: 29.7260 - val_mae: 3.0978
# Epoch 78/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.4694 - mae: 2.6775 - val_loss: 28.9980 - val_mae: 3.0710
# Epoch 79/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.9843 - mae: 2.7357 - val_loss: 32.6045 - val_mae: 3.2931
# Epoch 80/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.7558 - mae: 2.7622 - val_loss: 29.3212 - val_mae: 3.0494
# Epoch 81/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.4324 - mae: 2.7205 - val_loss: 28.6708 - val_mae: 3.0316
# Epoch 82/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.6890 - mae: 2.6391 - val_loss: 29.9829 - val_mae: 3.1274
# Epoch 83/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.0884 - mae: 2.6712 - val_loss: 28.8272 - val_mae: 3.2449
# Epoch 84/100
# 404/404 [==============================] - 3s 6ms/step - loss: 14.4973 - mae: 2.6835 - val_loss: 29.2222 - val_mae: 3.2802
# Epoch 85/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.2270 - mae: 2.6818 - val_loss: 28.5282 - val_mae: 3.2326
# Epoch 86/100
# 404/404 [==============================] - 2s 6ms/step - loss: 15.2191 - mae: 2.6966 - val_loss: 29.5661 - val_mae: 3.1336
# Epoch 87/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.5258 - mae: 2.7145 - val_loss: 28.9603 - val_mae: 3.1897
# Epoch 88/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.1124 - mae: 2.6759 - val_loss: 29.4928 - val_mae: 3.1714
# Epoch 89/100
# 404/404 [==============================] - 2s 6ms/step - loss: 14.8596 - mae: 2.6871 - val_loss: 35.4061 - val_mae: 3.5972
# Epoch 90/100
# 394/404 [============================>.] - ETA: 0s - loss: 14.6267 - mae: 2.7394

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scattergl(y=history.history['loss'],
name='Train'))
fig.add_trace(go.Scattergl(y=history.history['val_loss'],
name='Valid'))
fig.update_layout(height=500, width=700,
xaxis_title='Epoch',
yaxis_title='Loss')
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scattergl(y=history.history['mae'],
name='Train'))
fig.add_trace(go.Scattergl(y=history.history['val_mae'],
name='Valid'))
fig.update_layout(height=500,width=70,
xaxis_title='Epoch',
yaxis_title='Mean Absolute Error')
fig.show()

# %%
y_pred = model.predict(x_test)
mse_nn, mae_nn = model.evaluate(x_test, y_test)
print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)

# %%
from sklearn.metrics import mean_absolute_error
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
y_pred_lr = lr_model.predict(x_test)
mse_lr = mean_squared_error(y_test, y_pred_lr)
mae_lr = mean_absolute_error(y_test, y_pred_lr)
print('Mean squared error on test data: ', mse_lr)
print('Mean absolute error on test data: ', mae_lr)
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)

# %%
from sklearn.metrics import mean_squared_error
rmse=(np.sqrt(mean_squared_error(y_test,y_pred)))
print(rmse)
